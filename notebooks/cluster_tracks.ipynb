# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (14.0, 7.0)

# %%
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')
db = client.spotify

# %%
cursor = db.tracks.find()
tracks = []

for track in cursor:
    track = {
        'id':track['id'],
        'name':track['name'],
        'album':track['album']['name'],
        'artist':', '.join([artist['name'] for artist in track['artists']]),
        'popularity': track['popularity'],
        'danceability':track['audio_features']['danceability'],
        'energy':track['audio_features']['energy'],
        'acousticness':track['audio_features']['acousticness'],
        'valence':track['audio_features']['valence']
    }
    tracks.append(track)

df_tracks = pd.json_normalize(tracks)

# %%
df_tracks.head(10)
# Out:
#                        id                                               name  \
# 0  2dxjKgT0li4qBI3QwuN9Ih                                      Touch The Sky
# 1  4EnaOPZZ6tla9TWsRQaxYk                                      Write at Home
# 2  4FIMqjMdiZkTRcaqgES0ya                                                You
# 3  1jdlyu1JvtENUlxXntEife                                           The Life
# 4  769O71M6bzhU3ZXm1xF6VW  No Wrong No Right (feat. Robert Glasper, James...
# 5  5HS9dpiLOAT03qgv3lP5cR                                 Universal Language
# 6  0SPUNC31ZXVbadaj4M5TfD                                       Dumb It Down
# 7  1SgHNH36l41IIhuYGY4VCa                                       Pass Me Over
# 8  0FNPiAAdWdWaGr7JOnlKmi                                            Imagine
# 9  4hdeaFADWgq7KRByXqSwHq                                         All Matter
#
#                          album                                      artist  \
# 0            Late Registration                     Kanye West, Lupe Fiasco
# 1                Radio Silence  Talib Kweli, Datcha, Bilal, Robert Glasper
# 2              The Renaissance                                       Q-Tip
# 3                 Blak And Blu                              Gary Clark Jr.
# 4                   3ChordFold                              Terrace Martin
# 5  Chris Dave And The Drumhedz                 Chris Dave and The Drumhedz
# 6       Lupe Fiasco's The Cool       Lupe Fiasco, Gemstones, Graham Burris
# 7        Ain't Nobody Worryin'                            Anthony Hamilton
# 8    Tha Blue Carpet Treatment               Snoop Dogg, Dr. Dre, D'Angelo
# 9           Airtight's Revenge                                       Bilal
#
#    popularity  danceability  energy  acousticness  valence
# 0          66         0.524   0.846      0.011400    0.551
# 1          20         0.614   0.540      0.054000    0.156
# 2          24         0.532   0.848      0.484000    0.722
# 3          29         0.682   0.796      0.017200    0.761
# 4          21         0.572   0.641      0.002720    0.343
# 5          23         0.635   0.709      0.281000    0.622
# 6          37         0.703   0.768      0.147000    0.102
# 7          39         0.544   0.557      0.261000    0.482
# 8          55         0.803   0.627      0.286000    0.638
# 9          21         0.571   0.881      0.000113    0.636

# %%
df_tracks.sort_values('popularity', ascending=False).head(10)
# Out:
#                           id  \
# 330   5hVghJ4KaYES3BFUATCYn0
# 654   2374M0fQpWi3dLnB54qaLX
# 789   4u7EnebtmKWzUH433cf5Qv
# 1546  0wXuerDYiBnERgIpbb3JBR
# 472   6dGnYIeXmHdcikdzNNDMm2
# 801   3gdewACMIVMEWVbyb8O9sY
# 358   0d28khcov6AiegSCpG5TuT
# 985   7tqhbajSfrz2F7E1Z75ASX
# 144   3dhjNA0jGA8vHBQ1VdD6vV
# 733   4fzsfWzRhPawzqhX8Qt9F3
#
#                                                    name  \
# 330                                           EARFQUAKE
# 654                                              Africa
# 789                        Bohemian Rhapsody - 2011 Mix
# 1546                                            Redbone
# 472                Here Comes The Sun - Remastered 2009
# 801   Rocket Man (I Think It's Going To Be A Long, L...
# 358                                      Feel Good Inc.
# 985                       Ain't No Mountain High Enough
# 144                                    I Feel It Coming
# 733                                            Stronger
#
#                                      album                      artist  \
# 330                                   IGOR          Tyler, The Creator
# 654                                Toto IV                        TOTO
# 789   A Night At The Opera (2011 Remaster)                       Queen
# 1546                    "Awaken, My Love!"            Childish Gambino
# 472                Abbey Road (Remastered)                 The Beatles
# 801                          Honky Chateau                  Elton John
# 358                             Demon Days                    Gorillaz
# 985                                 United  Marvin Gaye, Tammi Terrell
# 144                                Starboy       The Weeknd, Daft Punk
# 733                             Graduation                  Kanye West
#
#       popularity  danceability  energy  acousticness  valence
# 330           83         0.554   0.498       0.23000    0.413
# 654           83         0.671   0.373       0.25700    0.732
# 789           83         0.414   0.404       0.27100    0.224
# 1546          82         0.743   0.347       0.16700    0.572
# 472           82         0.557   0.540       0.03390    0.394
# 801           81         0.601   0.532       0.43200    0.341
# 358           80         0.818   0.705       0.00836    0.772
# 985           80         0.663   0.600       0.43000    0.800
# 144           80         0.773   0.819       0.42800    0.585
# 733           80         0.617   0.717       0.00564    0.490

# %%
plt.figure()
# danceability
plt.subplot(221)
plt.hist(df_tracks['danceability'])
plt.title('danceability')
#energy
plt.subplot(222)
plt.hist(df_tracks['energy'])
plt.title('energy')
#acousticness
plt.subplot(223)
plt.hist(df_tracks['acousticness'])
plt.title('acousticness')
#valence
plt.subplot(224)
plt.hist(df_tracks['valence'])
plt.title('valence')
# Out:
# Text(0.5, 1.0, 'valence')

# %%
df_tracks[['name','album','artist','valence']].sort_values('valence', ascending=False).head(10)
# Out:
#                             name                                    album  \
# 750       It's The Same Old Song                   Four Tops Second Album
# 1374               Eu Vou Torcer                     A Tabua De Esmeralda
# 389         La Illaha Illa Allah  Soirées Gnawa Neurasys Remaster, Vol. 5
# 390                  Kamil Ladou  Soirées Gnawa Neurasys Remaster, Vol.10
# 660         You Know What I Mean                             Blow By Blow
# 381             Feira de Mangaio                 Cada um Belisca um Pouco
# 1063  Lady Day and John Coltrane     The Revolution Will Not Be Televised
# 1401    When It Comes Down To It                   Adventures In Paradise
# 825                  Bottom's Up                              Bottom's Up
# 1411              The Seed (2.0)                               Phrenology
#
#                                                  artist  valence
# 750                                           Four Tops    0.977
# 1374                                      Jorge Ben Jor    0.977
# 389                                      Hamid El Kasri    0.971
# 390                                      Hamid El Kasri    0.971
# 660                                           Jeff Beck    0.971
# 381                    Dominguinhos, Sivuca, Oswaldinho    0.970
# 1063                                    Gil Scott-Heron    0.969
# 1401                                    Minnie Riperton    0.968
# 825   Victor Bailey, Victor Bailey bass/keyboards/vo...    0.967
# 1411                           The Roots, Cody Chesnutt    0.966

# %%
df_tracks[['name','album','artist','energy']].sort_values('energy', ascending=False).head(10)
# Out:
#                               name                      album  \
# 1195                When Doves Cry                Purple Rain
# 873        Soul With A Capital 'S'                     T.O.P.
# 625               Calm Like a Bomb  The Battle Of Los Angeles
# 1020                          Jefe              Culcha Vulcha
# 990                     Move on Up                 Move on Up
# 593                   Forró Brasil    Ao Vivo (Remasterizado)
# 923   How Could You Break My Heart              Roads of Life
# 704              Crosstown Traffic          Electric Ladyland
# 301                   Teddy Picker  Favourite Worst Nightmare
# 375                Public Interest                 Beat Music
#
#                         artist  energy
# 1195                    Prince   0.989
# 873             Tower Of Power   0.972
# 625   Rage Against The Machine   0.970
# 1020              Snarky Puppy   0.969
# 990            Curtis Mayfield   0.969
# 593            Hermeto Pascoal   0.966
# 923               Bobby Womack   0.964
# 704               Jimi Hendrix   0.963
# 301             Arctic Monkeys   0.963
# 375              Mark Guiliana   0.958

# %%
df_tracks[['name','album','artist','danceability']].sort_values('danceability', ascending=False).head(10)
# Out:
#                                  name                     album  \
# 142                  Around the World                  Homework
# 1474                        The Light  Like Water For Chocolate
# 950             You're The Reason Why         The Long Way Home
# 1002                       Mad Issues             Mahogany Soul
# 1456                      Devil's Pie                    Voodoo
# 1512  Who Is He And What Is He To You      Peace Beyond Passion
# 1453            Feel Like Makin' Love                    Voodoo
# 216                       Boogie Down                   Jarreau
# 1180            Workin' Day and Night              Off the Wall
# 966                      Crying Shame         Half Mile Harvest
#
#                    artist  danceability
# 142             Daft Punk         0.956
# 1474               Common         0.939
# 950          Aaron Taylor         0.935
# 1002          Angie Stone         0.918
# 1456             D'Angelo         0.917
# 1512  Meshell Ndegeocello         0.914
# 1453             D'Angelo         0.913
# 216            Al Jarreau         0.913
# 1180      Michael Jackson         0.907
# 966   The Teskey Brothers         0.903

# %%
df_tracks[['name','album','artist','acousticness']].sort_values('acousticness', ascending=False).head(10)
# Out:
#                                            name  \
# 955                           Gnossienne: No. 1
# 321          Goldberg Variations, BWV 988: Aria
# 1726           I'm Gettin' Sentimental Over You
# 269                                      Romain
# 416                                       Smile
# 696                                    Ballad Z
# 1729                          I Hear A Rhapsody
# 84                                        Lilac
# 185   What Are You Doing The Rest Of Your Life?
# 1605                            Interlude No. 3
#
#                                                   album  \
# 955   Satie: Avant-dernières pensées (Bonus Track Ve...
# 321   Bach: The Goldberg Variations, BWV 988 (1981 G...
# 1726                                       Undercurrent
# 269                                        Undercurrent
# 416                                  Hollywood Africans
# 696                              Jim Hall & Pat Metheny
# 1729                                       Undercurrent
# 84                                             Mockroot
# 185               From Left To Right (Expanded Edition)
# 1605                             The Mourning of a Star
#
#                                   artist  acousticness
# 955        Erik Satie, Alexandre Tharaud         0.996
# 321   Johann Sebastian Bach, Glenn Gould         0.995
# 1726                Bill Evans, Jim Hall         0.995
# 269                 Bill Evans, Jim Hall         0.995
# 416                          Jon Batiste         0.995
# 696                Jim Hall, Pat Metheny         0.995
# 1729                Bill Evans, Jim Hall         0.995
# 84                       Tigran Hamasyan         0.994
# 185                           Bill Evans         0.993
# 1605                       Keith Jarrett         0.993

# %%
audio_features = df_tracks[['danceability','energy','acousticness','valence']]
audio_features.describe()
# Out:
#        danceability      energy  acousticness      valence
# count   1730.000000  1730.00000   1730.000000  1730.000000
# mean       0.571191     0.49564      0.451230     0.498242
# std        0.164131     0.22748      0.330361     0.256640
# min        0.000000     0.00211      0.000113     0.000000
# 25%        0.452250     0.33600      0.137250     0.283000
# 50%        0.578000     0.50450      0.407500     0.497000
# 75%        0.695750     0.67000      0.776500     0.713000
# max        0.956000     0.98900      0.996000     0.977000

# %%
np.cov(audio_features.values[:,0],audio_features.values[:,3])
# Out:
# array([[0.02693902, 0.02397951],
#        [0.02397951, 0.06586384]])

# %%
np.corrcoef(audio_features.values[:,0],audio_features.values[:,3])
# Out:
# array([[1.        , 0.56928004],
#        [0.56928004, 1.        ]])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
X_scaled = StandardScaler().fit_transform(audio_features)

# %%
k = range(1,12,1)

#-- lista de inércias
inertias = []

#-- para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X_scaled)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %%
from sklearn.cluster import KMeans

n = 4
kmeans = KMeans(n_clusters=n)

# %%
kmeans.fit(X_scaled)
labels = kmeans.labels_

plt.scatter(x=X_scaled[:,3],
            y=X_scaled[:,0],
            c=labels.astype(np.float),
            cmap='rainbow',
            edgecolor='k')
plt.title('Num clusters: {}'.format(n))
plt.show()

# %%
labels = kmeans.fit_predict(X_scaled)

# %%
#-- verificando o balanceamento dos clusters
label, count = np.unique(labels, return_counts=True)
for l, c in zip(label,count):
    print('Cluster {}: {}'.format(l,c))
# Out:
# Cluster 0: 364
# Cluster 1: 529
# Cluster 2: 416
# Cluster 3: 421

# %%
df_tracks = df_tracks.join(pd.DataFrame(labels, columns=['cluster']))

# %% [markdown]
# ### Exibe as infromações dos clusters

# %%
clusters = df_tracks \
    .groupby('cluster') \
    .agg('mean')

clusters
# Out:
#          popularity  danceability    energy  acousticness   valence
# cluster
# 0         34.348901      0.631783  0.431723      0.657070  0.575712
# 1         38.733459      0.718837  0.657854      0.190636  0.743896
# 2         32.552885      0.414280  0.217712      0.848877  0.218800
# 3         35.890736      0.488325  0.621701      0.207780  0.398711

# %%
df_tracks[df_tracks['cluster']==3]
# Out:
#                           id  \
# 0     2dxjKgT0li4qBI3QwuN9Ih
# 1     4EnaOPZZ6tla9TWsRQaxYk
# 4     769O71M6bzhU3ZXm1xF6VW
# 6     0SPUNC31ZXVbadaj4M5TfD
# 7     1SgHNH36l41IIhuYGY4VCa
# ...                      ...
# 1686  1HUWYxXGQMQ63QkIdi6omV
# 1697  0iJP3XxZNE8tP7YnB23J1r
# 1706  2qyqM3EcFc3s5MNlnJpiTJ
# 1708  2lSyDjRL30hdy74gDM9x3L
# 1722  1o7YJ27NtE8TbAUPm0DDa2
#
#                                                    name  \
# 0                                         Touch The Sky
# 1                                         Write at Home
# 4     No Wrong No Right (feat. Robert Glasper, James...
# 6                                          Dumb It Down
# 7                                          Pass Me Over
# ...                                                 ...
# 1686                             Love Having You Around
# 1697                          Someday We'll All Be Free
# 1706                                          Mr. Clean
# 1708                                       One for Duke
# 1722                                            Perugia
#
#                        album                                      artist  \
# 0          Late Registration                     Kanye West, Lupe Fiasco
# 1              Radio Silence  Talib Kweli, Datcha, Bilal, Robert Glasper
# 4                 3ChordFold                              Terrace Martin
# 6     Lupe Fiasco's The Cool       Lupe Fiasco, Gemstones, Graham Burris
# 7      Ain't Nobody Worryin'                            Anthony Hamilton
# ...                      ...                                         ...
# 1686        Music Of My Mind                               Stevie Wonder
# 1697      Extension Of A Man                              Donny Hathaway
# 1706           Straight Life                             Freddie Hubbard
# 1708           Skull Session                               Oliver Nelson
# 1722                 Crystal                                 Ahmad Jamal
#
#       popularity  danceability  energy  acousticness  valence  cluster
# 0             66         0.524   0.846       0.01140    0.551        3
# 1             20         0.614   0.540       0.05400    0.156        3
# 4             21         0.572   0.641       0.00272    0.343        3
# 6             37         0.703   0.768       0.14700    0.102        3
# 7             39         0.544   0.557       0.26100    0.482        3
# ...          ...           ...     ...           ...      ...      ...
# 1686          33         0.629   0.759       0.45500    0.491        3
# 1697          32         0.379   0.413       0.45100    0.249        3
# 1706           6         0.390   0.696       0.27100    0.818        3
# 1708           0         0.497   0.641       0.43200    0.383        3
# 1722          11         0.400   0.465       0.35800    0.708        3
#
# [421 rows x 10 columns]

# %%
for track in df_tracks.itertuples():
    update = {'cluster':track.cluster}
    db.tracks.update({'id':track.id},{"$set": update}, upsert=False)
# Out:
# D:\Programas\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.neighbors import KNeighborsClassifier
